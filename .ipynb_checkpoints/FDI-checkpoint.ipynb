# %%
import pandas as pd

# %%
df = pd.read_csv('API_BDI.csv')

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0      Burundi          BDI
# 1      Burundi          BDI
# 2      Burundi          BDI
# 3      Burundi          BDI
# 4      Burundi          BDI
#
#                                       Indicator Name     Indicator Code  1960  \
# 0                    Export value index (2000 = 100)  TX.VAL.MRCH.XD.WD   NaN
# 1  Insurance and financial services (% of commerc...  TX.VAL.INSF.ZS.WT   NaN
# 2  Merchandise imports by the reporting economy, ...  TM.VAL.MRCH.RS.ZS   NaN
# 3            Food imports (% of merchandise imports)  TM.VAL.FOOD.ZS.UN   NaN
# 4  Share of tariff lines with international peaks...  TM.TAX.MRCH.IP.ZS   NaN
#
#    1961  1962  1963  1964       1965  ...        2010        2011        2012  \
# 0   NaN   NaN   NaN   NaN        NaN  ...  202.294159  246.879917  266.884834
# 1   NaN   NaN   NaN   NaN        NaN  ...   21.573482   21.182800   19.171061
# 2   NaN   NaN   NaN   NaN        NaN  ...    9.351707   11.699630    8.933576
# ...

# %%
df = df[['Country Name','Country Code','Indicator Name','2010', '2011','2012','2013','2014', '2015', '2016', '2017', '2018', '2019']]

# %%
df.head(30)
# Out:
#             2010          2011          2012          2013          2014  \
# 0   2.022942e+02  2.468799e+02  2.668848e+02  1.883421e+02  2.638802e+02
# 1   2.157348e+01  2.118280e+01  1.917106e+01  1.900598e+01  1.134798e+01
# 2   9.351707e+00  1.169963e+01  8.933576e+00  6.076320e-02  8.240224e-02
# 3   1.378979e+01  2.467622e+01  3.013399e+01  1.398723e+01  1.306191e+01
# 4   3.287421e+01  3.266484e+01  3.407158e+01  3.067799e+01  3.081542e+01
# 5   1.800000e+06  2.500000e+06  1.500000e+06  2.300000e+06  4.100000e+06
# 6   8.660000e+01           NaN           NaN           NaN           NaN
# 7   2.103618e-01  2.219461e-01  2.292873e-01  2.312906e-01  2.276004e-01
# 8   1.975838e+00  2.035172e+00  2.077865e+00  2.102397e+00  2.107510e+00
# 9   5.269882e+01  5.268965e+01  5.264439e+01  5.256664e+01  5.247395e+01
# 10  4.447612e+01  4.450235e+01  4.456578e+01  4.465640e+01  4.474849e+01
# 11  5.920000e+01  5.610000e+01  5.320000e+01  5.040000e+01  4.790000e+01
# ...
